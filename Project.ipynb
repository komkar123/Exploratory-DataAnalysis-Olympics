# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mt
import seaborn as sns
# %matplotlib notebook

# %%
df_a=pd.read_csv(r'C:\Users\DELL\Downloads\athlete_events.csv')
df_noc=pd.read_csv(r'C:\Users\DELL\Downloads\noc_regions.csv')

# %%
#df=pd.pivot_table(data=df_a,index=['ID','Year','Team','Name','Sex','Age','Height','Weight','NOC','Games','Season','City','Sport','Event','Medal'],columns='Medal',aggfunc=len)

# %%
df_a=df_a[['Year','Team','Season','Name','Sex','Age','Height','Weight','Games','City','Sport','Event','Medal']]

# %%
#pd.pivot_table(data=df_a,index=['Year','Team','Season','Season','Event','Medal'],columns='Medal',aggfunc=len,dropna=False)

# %%
df_a['Gold']=df_a['Medal'].apply(lambda x: 1 if x=='Gold' else 0)
df_a['Silver']=df_a['Medal'].apply(lambda x: 1 if x=='Silver' else 0)
df_a['Bronze']=df_a['Medal'].apply(lambda x: 1 if x=='Bronze' else 0)
df_a['None']=df_a['Medal'].apply(lambda x: 1 if x==None else 0)

# %%
df_a['Total']=df_a['Gold']+df_a['Silver']+df_a['Bronze']

# %%
#df=df.rename_axis(None,axis=1)

df_a['Team']=df_a['Team'].replace({'Soviet Union':'Russia','Soviet Union-1':'Russia','Soviet Union-2':'Russia','Soviet Union-3':'Russia',})

#df['Total']=df['Bronze']+df['Gold']+df['Silver']

# %%
df=pd.DataFrame(df_a.groupby(['Year','Team'])['Gold','Silver','Bronze','Total'].sum())

# %%
df.reset_index(inplace=True)

# %%
ru=df[df['Team']=='Russia']
us=df[df['Team']=='United States']
ch=df[df['Team']=='China']
gr=df[df['Team']=='Germany']

# %%
plt.style.use('seaborn-colorblind')

# %%
df['Gold %']=df['Gold']/df['Total']

# %%
df
# Out:
#       Year                           Team  Gold  Silver  Bronze  Total  \
# 0     1896                      Australia     2       0       0      2
# 1     1896        Australia/Great Britain     0       0       2      2
# 2     1896                        Austria     2       1       2      5
# 3     1896                        Denmark     1       2       3      6
# 4     1896  Ethnikos Gymnastikos Syllogos     0       0       2      2
# ...    ...                            ...   ...     ...     ...    ...
# 5143  2016                      Venezuela     0       1       2      3
# 5144  2016                        Vietnam     1       1       0      2
# 5145  2016                          Yemen     0       0       0      0
# 5146  2016                         Zambia     0       0       0      0
# 5147  2016                       Zimbabwe     0       0       0      0
#
#         Gold %
# 0     1.000000
# 1     0.000000
# 2     0.400000
# 3     0.166667
# 4     0.000000
# ...        ...
# ...

# %%
gr
# Out:
#       Year     Team  Gold  Silver  Bronze  Total    Gold %
# 6     1896  Germany    24       5       2     31  0.774194
# 101   1900  Germany     1       1       0      2  0.500000
# 227   1904  Germany     4       5       6     15  0.266667
# 302   1906  Germany    14      10       6     30  0.466667
# 362   1908  Germany     4      11       4     19  0.210526
# 436   1912  Germany     6      19      14     39  0.153846
# 709   1928  Germany    21      15      41     77  0.272727
# 788   1932  Germany    10      26      17     53  0.188679
# 885   1936  Germany    93      72      55    220  0.422727
# 1143  1952  Germany     4      16      25     45  0.088889
# 1294  1956  Germany    10      20      24     54  0.185185
# 1465  1960  Germany    38      35      20     93  0.408602
# 1660  1964  Germany    25      43      53    121  0.206612
# 2780  1992  Germany    93      66      65    224  0.415179
# 2978  1994  Germany    14      10       6     30  0.466667
# ...

# %%
ru=df[df['Team']=='Russia']
us=df[df['Team']=='United States']
ch=df[df['Team']=='China']
gr=df[df['Team']=='Germany']

# %%
ru=ru[ru['Year']>1990]
ch=ch[ch['Year']>1990]
us=us[us['Year']>1990]

# %%
# Out:
#     level_0  index  Year   Team  Gold  Silver  Bronze  Total    Gold %
# 0         1   2963  1994  China     0       1       2      3  0.000000
# 1         2   3093  1996  China    13      66      15     94  0.138298
# 2         3   3309  1998  China     0       9       5     14  0.000000
# 3         4   3445  2000  China    31      19      15     65  0.476923
# 4         5   3660  2002  China     2       5       7     14  0.142857
# 5         6   3804  2004  China    42      27      13     82  0.512195
# 6         7   4034  2006  China     2       3       4      9  0.222222
# 7         8   4180  2008  China    72      49      49    170  0.423529
# 8         9   4442  2010  China     7       1       7     15  0.466667
# 9        10   4579  2012  China    50      38      29    117  0.427350
# 10       11   4802  2014  China     3       4       5     12  0.250000
# 11       12   4949  2016  China    44      30      35    109  0.403670

# %%
us.reset_index(inplace=True)

# %%
ch.reset_index(inplace=True)

# %%
ru.reset_index(inplace=True)

# %%
ch=ch[ch['Year']>1992]
us=us[us['Year']>1992]

# %%
ch.reset_index(inplace=True)
us.reset_index(inplace=True)

# %%
#pd.concat([ru['Gold'],us['Gold']],axis=1)


g=pd.DataFrame({'Year':ch['Year'],'China':ch['Gold'],'USA':us['Gold'],'Russia':ru['Gold']})

# %%
g.set_index('Year',inplace=True)

# %%
ax=g.plot.barh(stacked=True)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel('Number of Gold Medals')
plt.title('Gold Medals won by Russia, US & China [1994-2016]')
plt.legend(fontsize='x-small')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s=pd.DataFrame({'Year':ch['Year'],'USA':us['Silver'],'Russia':ru['Gold']})

# %%
df_a.groupby(['Year','Team','Sport']).sum()


df_a[df_a['Team']=='United States']
# Out:
#         Year           Team  Season                        Name Sex   Age  \
# 10      1992  United States  Winter             Per Knut Aaland   M  31.0
# 11      1992  United States  Winter             Per Knut Aaland   M  31.0
# 12      1992  United States  Winter             Per Knut Aaland   M  31.0
# 13      1992  United States  Winter             Per Knut Aaland   M  31.0
# 14      1994  United States  Winter             Per Knut Aaland   M  33.0
# ...      ...            ...     ...                         ...  ..   ...
# 270850  2004  United States  Summer                    Rami Zur   M  27.0
# 270851  2008  United States  Summer                    Rami Zur   M  31.0
# 270852  2008  United States  Summer                    Rami Zur   M  31.0
# 271044  1964  United States  Summer  Victor Andrew "Vic" Zwolak   M  25.0
# 271107  1972  United States  Summer  James Francis "Jim" Zylker   M  21.0
#
#         Height  Weight        Games         City                 Sport  \
# ...

# %%
sns.jointplot(s['USA'],s['Russia'])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig,ax=plt.subplots()
ax.barh(us['Year'],us['Gold'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ch[['Gold','Silver','Bronze','Year']].plot.bar('Year')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(ch['Year'],ch['Gold %'])
plt.plot(us['Year'],us['Gold %'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#sns.jointplot(us[['Gold %']],ch[['Gold %']])

# %%
us['Gold %'].plot.kde()

# %%
plt.plot(us['Year'],us['Gold %'])
plt.plot(ch['Year'],ch['Gold %'])
plt.plot(ru['Year'],ru['Gold %'])
plt.plot(gr['Year'],gr['Gold %'])

# %%
us.plot()
ru.plot.line('Year','Total')

# %%
plt.plot(us['Year'],us['Gold'])
plt.plot(ch['Year'],ch['Gold'])
plt.plot(ru['Year'],ru['Gold'])
plt.plot(gr['Year'],gr['Gold'])

# %%
from pandas.plotting import parallel_coordinates
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(ru);

# %%
us[['Gold','Silver','Bronze']].plot.box()

# %%
ru[['Gold','Silver','Bronze']].plot.box()

# %%
df_a
# Out:
#         Year            Team  Season                      Name Sex   Age  \
# 0       1992           China  Summer                 A Dijiang   M  24.0
# 1       2012           China  Summer                  A Lamusi   M  23.0
# 2       1920         Denmark  Summer       Gunnar Nielsen Aaby   M  24.0
# 3       1900  Denmark/Sweden  Summer      Edgar Lindenau Aabye   M  34.0
# 4       1988     Netherlands  Winter  Christine Jacoba Aaftink   F  21.0
# ...      ...             ...     ...                       ...  ..   ...
# 271111  1976        Poland-1  Winter                Andrzej ya   M  29.0
# 271112  2014          Poland  Winter                  Piotr ya   M  27.0
# 271113  2014          Poland  Winter                  Piotr ya   M  27.0
# 271114  1998          Poland  Winter        Tomasz Ireneusz ya   M  30.0
# 271115  2002          Poland  Winter        Tomasz Ireneusz ya   M  34.0
#
#         Height  Weight        Games            City          Sport  \
# ...

# %%
#df.plot.scatter('Bronze','Gold',c=df['Total'],colormap='viridis')
df['Total']=df['Bronze']+df['Gold']+df['Silver']

# %%
df.groupby('Year').sort_values('Total')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-454-e8945d4af697> in <module>
# ----> 1 df.groupby('Year').sort_values('Total')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'sort_values' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
df=df.sort_values('Total',ascending=False).groupby('Year').head(5).sort_index()

# %%
df
# Out:
#                     Gold  Silver  Bronze  Total
# Year Team
# 1896 France            5       4       2     11
#      Germany          24       5       2     31
#      Great Britain     2       3       2      7
#      Greece           10      16      18     44
#      United States    11       7       2     20
# ...                  ...     ...     ...    ...
# 2016 China            44      30      35    109
#      Germany          47      43      67    157
#      Great Britain    64      55      26    145
#      Russia           50      28      35    113
#      United States   137      52      67    256
#
# [175 rows x 4 columns]

# %%
x=df.reset_index()

# %%
x.plot.scatter('Year','Total')

# %%
un=x[x['Team']=='United States']
ru=x[x['Team']=='Russia']
ch=x[x['Team']=='China']

# %%
un.plot.line('Year','Total')
ru.plot.line('Year','Total')
ch.plot.line('Year','Total')

# %%
plt.plot(un['Year'],un['Total'])
plt.plot(ru['Year'],ru['Total'])
plt.plot(ch['Year'],ch['Total'])

# %%
df.reset_index(inplace=True)

# %%
x[x['Team']=='China']
# Out:
#      Year   Team  Gold  Silver  Bronze  Total
# 111  1992  China    14      44      15     73
# 121  1996  China    13      66      15     94
# 151  2008  China    72      49      49    170
# 161  2012  China    50      38      29    117
# 170  2016  China    44      30      35    109

# %%
#df.sort_values('Total').groupby(level=).head().sort_index()

# %%
x=df.sort_values(['Year','Total'],ascending=False)

# %%
d=df.sort_values('Total',ascending=False)

# %%
y=df.sort_values(['Year','Total'])

# %%
x
# Out:
#                     Gold  Silver  Bronze  Total
# Year Team
# 2016 United States   137      52      67    256
#      Germany          47      43      67    157
#      Great Britain    64      55      26    145
#      Russia           50      28      35    113
#      China            44      30      35    109
# ...                  ...     ...     ...    ...
# 1896 Greece-1          0       2       0      2
#      Greece-2          0       0       0      0
#      Greece-3          0       0       0      0
#      Italy             0       0       0      0
#      Sweden            0       0       0      0
#
# [5170 rows x 4 columns]

# %%
x
# Out:
#                     Gold  Silver  Bronze  Total
# Year Team
# 2016 United States   137      52      67    256
#      Germany          47      43      67    157
#      Great Britain    64      55      26    145
#      Russia           50      28      35    113
#      China            44      30      35    109
# ...                  ...     ...     ...    ...
# 1896 Greece-1          0       2       0      2
#      Greece-2          0       0       0      0
#      Greece-3          0       0       0      0
#      Italy             0       0       0      0
#      Sweden            0       0       0      0
#
# [5170 rows x 4 columns]

# %%
x.groupby('Team').head()
# Out:
#                       Gold  Silver  Bronze  Total
# Year Team
# 1980 Soviet Union      201     156     131    488
# 1984 United States     190     119      50    359
# 1988 Soviet Union      168      77     107    352
# 1976 Soviet Union      148     100      88    336
# 2008 United States     121     110      78    309
# ...                    ...     ...     ...    ...
# 1984 North Yemen         0       0       0      0
# 1976 Soviet Union-3      0       0       0      0
#      West Germany-2      0       0       0      0
#      Great Britain-3     0       0       0      0
#      Italy-3             0       0       0      0
#
# [2431 rows x 4 columns]

# %%
df1=df.groupby(['Year','Team'])

# %%
df.apply(lambda x: )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-790800ce7ef9> in <module>
# ----> 1 df.apply(lambda x: x.groupby('Total'))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
# ...

# %%
x[x['Team']=='United States']
# Out:
#       Year           Team  Total
# 17    1896  United States     20
# 200   1900  United States     45
# 267   1904  United States    199
# 338   1906  United States     24
# 407   1908  United States     65
# 510   1912  United States    107
# 584   1920  United States    194
# 673   1924  United States    186
# 758   1928  United States     92
# 829   1932  United States    190
# 959   1936  United States    108
# 1091  1948  United States    149
# 1242  1952  United States    144
# 1392  1956  United States    143
# 1581  1960  United States    145
# 1783  1964  United States    165
# 1930  1968  United States    173
# 2085  1972  United States    195
# 2215  1976  United States    173
# 2326  1980  United States     30
# 2501  1984  United States    359
# 2710  1988  United States    212
# 2949  1992  United States    236
# 3057  1994  United States     19
# 3300  1996  United States    255
# 3410  1998  United States     30
# 3650  2000  United States    240
# ...

# %%
df=df.reset_index()

# %%
df[df['Name']=='Janne Petteri Ahonen']
# Out:
# Medal    ID  Year     Team                  Name Sex   Age  Height  Weight  \
# 227    1435  2002  Finland  Janne Petteri Ahonen   M  24.0   184.0    66.0
# 228    1435  2006  Finland  Janne Petteri Ahonen   M  28.0   184.0    66.0
#
# Medal  NOC        Games  Season            City        Sport  \
# 227    FIN  2002 Winter  Winter  Salt Lake City  Ski Jumping
# 228    FIN  2006 Winter  Winter          Torino  Ski Jumping
#
# Medal                               Event   Medal  Bronze  Gold  Silver  Total
# 227    Ski Jumping Men's Large Hill, Team  Silver     NaN   NaN     1.0    NaN
# 228    Ski Jumping Men's Large Hill, Team  Silver     NaN   NaN     1.0    NaN

# %%
df[df['Medal'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Year, Team, Name, Sex, Age, Height, Weight, NOC, Games, Season, City, Sport, Event, Medal, Bronze, Gold, Silver, Total]
# Index: []

# %%
df[df['Name']=='Launceston Elliot']
# Out:
#          ID  Year           Team               Name Sex   Age  Height  Weight  \
# 6350  32330  1896  Great Britain  Launceston Elliot   M  21.0   188.0   102.0
# 6351  32330  1896  Great Britain  Launceston Elliot   M  21.0   188.0   102.0
#
#       NOC        Games  Season    City          Sport  \
# 6350  GBR  1896 Summer  Summer  Athina  Weightlifting
# 6351  GBR  1896 Summer  Summer  Athina  Weightlifting
#
#                                          Event  Bronze  Gold  Silver
# 6350   Weightlifting Men's Unlimited, One Hand       0     1       0
# 6351  Weightlifting Men's Unlimited, Two Hands       0     0       1

# %%
df
# Out:
#                                       Age                City               \
# Medal                              Bronze  Gold Silver Bronze  Gold Silver
# Year Team
# 1896 Australia                        NaN   2.0    NaN    NaN   2.0    NaN
#      Australia/Great Britain          2.0   NaN    NaN    2.0   NaN    NaN
#      Austria                          2.0   2.0    1.0    2.0   2.0    1.0
#      Denmark                          3.0   1.0    2.0    3.0   1.0    2.0
#      Ethnikos Gymnastikos Syllogos    2.0   NaN    NaN    2.0   NaN    NaN
# ...                                   ...   ...    ...    ...   ...    ...
# 2016 Montenegro                       NaN   NaN    NaN    NaN   NaN    NaN
#      Fiji                             NaN  13.0    NaN    NaN  13.0    NaN
#      Jordan                           NaN   1.0    NaN    NaN   1.0    NaN
#      Kosovo                           NaN   1.0    NaN    NaN   1.0    NaN
# ...
